# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\dell\anaconda3\lib\site-packages (4.1.2)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\users\dell\anaconda3\lib\site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyspark findspark
# Out:
# Requirement already satisfied: pyspark in c:\users\dell\anaconda3\lib\site-packages (4.1.2)
# Requirement already satisfied: findspark in c:\users\dell\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\users\dell\anaconda3\lib\site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspark 
from pyspark import SparkContext, SparkConf 
from pyspark.sql import SparkSession 
c = pyspark.SparkConf().setAppName("test_app").setMaster("local") 
sc = pyspark.SparkContext(conf = c) 
spark = SparkSession(sc)

# %%
import findspark

# %%
findspark.find()
# Out:
# 'C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Software\\Spark\\spark-4.0.2-bin-hadoop3'
