# %%
import pyspark 
from pyspark import SparkContext, SparkConf 
from pyspark.sql import SparkSession 
c = pyspark.SparkConf().setAppName("test_app").setMaster("local") 
sc = pyspark.SparkContext(conf = c) 
spark = SparkSession(sc)

# %%
from pyspark.sql.functions import *

# %%
import time

# %%
data =spark.read.csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\Car_Data.csv" , header = True , inferSchema = True)

# %%
type(data)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
data.head(3)  # in pandas it will work but in spark not this show command works
# Out:
# [Row(Car_Name='ritz', Year=2014, Selling_Price=3.35, Present_Price=5.59, Kms_Driven=27000, Fuel_Type='Petrol', Seller_Type='Dealer', Transmission='Manual', Car_Owner='1st Owner'),
#  Row(Car_Name='sx4', Year=2013, Selling_Price=4.75, Present_Price=9.54, Kms_Driven=43000, Fuel_Type='Diesel', Seller_Type='Dealer', Transmission='Manual', Car_Owner='1st Owner'),
#  Row(Car_Name='ciaz', Year=2017, Selling_Price=7.25, Present_Price=9.85, Kms_Driven=6900, Fuel_Type='Petrol', Seller_Type='Dealer', Transmission='Manual', Car_Owner='1st Owner')]

# %%
data.show(6, False)
# Out:
# +-------------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name     |Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +-------------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |ritz         |2014|3.35         |5.59         |27000     |Petrol   |Dealer     |Manual      |1st Owner|
# |sx4          |2013|4.75         |9.54         |43000     |Diesel   |Dealer     |Manual      |1st Owner|
# |ciaz         |2017|7.25         |9.85         |6900      |Petrol   |Dealer     |Manual      |1st Owner|
# |wagon r      |2011|2.85         |4.15         |5200      |Petrol   |Dealer     |Manual      |1st Owner|
# |swift        |2014|4.6          |6.87         |42450     |Diesel   |Dealer     |Manual      |2nd Owner|
# |vitara brezza|2018|9.25         |9.83         |2071      |Diesel   |Dealer     |Manual      |2nd Owner|
# ...

# %%
# task on pyspark

# %%
start_time = time.time()
data = spark.read.csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\accepted_2007_to_2018Q4.csv")   #1.55GB of Data
end_time = time.time()
execution_time = end_time - start_time
print(f"Time Taken to run/load the data: {execution_time} seconds")
# Out:
# Time Taken to run/load the data: 0.24193191528320312 seconds

# %%
import pandas as pd

# %%
start_time = time.time()
data = pd.read_csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\accepted_2007_to_2018Q4.csv")   #1.55GB of Data
end_time = time.time()
execution_time = end_time - start_time
print(f"Time Taken to run/load the data: {execution_time} seconds")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15952\2202921116.py:2: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\accepted_2007_to_2018Q4.csv")   #1.55GB of Data
# Time Taken to run/load the data: 80.52749013900757 seconds

# %%
# Any function will start with spark

data =spark.read.csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\Car_Data.csv" , header = True)

# %%
data.show(9)
# Out:
# +-------------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |     Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +-------------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |         ritz|2014|         3.35|         5.59|     27000|   Petrol|     Dealer|      Manual|1st Owner|
# |          sx4|2013|         4.75|         9.54|     43000|   Diesel|     Dealer|      Manual|1st Owner|
# |         ciaz|2017|         7.25|         9.85|      6900|   Petrol|     Dealer|      Manual|1st Owner|
# |      wagon r|2011|         2.85|         4.15|      5200|   Petrol|     Dealer|      Manual|1st Owner|
# |        swift|2014|          4.6|         6.87|     42450|   Diesel|     Dealer|      Manual|2nd Owner|
# |vitara brezza|2018|         9.25|         9.83|      2071|   Diesel|     Dealer|      Manual|2nd Owner|
# ...

# %%
data.shape # will not work will work only in pandas
# Out:
# ---------------------------------------------------------------------------
# PySparkAttributeError                     Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.shape # will not work will work only in pandas
#
# File ~\anaconda3\Lib\site-packages\pyspark\sql\classic\dataframe.py:995, in DataFrame.__getattr__(self, name)
#     993 def __getattr__(self, name: str) -> Column:
#     994     if name not in self.columns:
# --> 995         raise PySparkAttributeError(
#     996             errorClass="ATTRIBUTE_NOT_SUPPORTED", messageParameters={"attr_name": name}
#     997         )
#     998     jc = self._jdf.apply(name)
#     999     return Column(jc)
#
# PySparkAttributeError: [ATTRIBUTE_NOT_SUPPORTED] Attribute `shape` is not supported.

# %%
data.dtypes
# Out:
# [('Car_Name', 'string'),
#  ('Year', 'string'),
#  ('Selling_Price', 'string'),
#  ('Present_Price', 'string'),
#  ('Kms_Driven', 'string'),
#  ('Fuel_Type', 'string'),
#  ('Seller_Type', 'string'),
#  ('Transmission', 'string'),
#  ('Car_Owner', 'string')]

# %%
data.dtypes
# Out:
# [('Car_Name', 'string'),
#  ('Year', 'string'),
#  ('Selling_Price', 'string'),
#  ('Present_Price', 'string'),
#  ('Kms_Driven', 'string'),
#  ('Fuel_Type', 'string'),
#  ('Seller_Type', 'string'),
#  ('Transmission', 'string'),
#  ('Car_Owner', 'string')]

# %%
data.printSchema()
# Out:
# root
#  |-- Car_Name: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Selling_Price: string (nullable = true)
#  |-- Present_Price: string (nullable = true)
#  |-- Kms_Driven: string (nullable = true)
#  |-- Fuel_Type: string (nullable = true)
#  |-- Seller_Type: string (nullable = true)
#  |-- Transmission: string (nullable = true)
#  |-- Car_Owner: string (nullable = true)

# %%
data.count()
# Out:
# 301

# %%
data.columns
# Out:
# ['Car_Name',
#  'Year',
#  'Selling_Price',
#  'Present_Price',
#  'Kms_Driven',
#  'Fuel_Type',
#  'Seller_Type',
#  'Transmission',
#  'Car_Owner']

# %%
data.count(),len(data.columns)
# Out:
# (301, 9)

# %%
# Out:
# +--------+----+
# |Car_Name|Year|
# +--------+----+
# |    ritz|2014|
# |     sx4|2013|
# |    ciaz|2017|
# | wagon r|2011|
# |   swift|2014|
# +--------+----+
# only showing top 5 rows

# %%
data2 =spark.read.csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\investment_banking.csv" , header = True )

# %%
data2.show(5)
# Out:
# +---------+-----------------+-------------------+--------------------+------------+----------+----------+----------+------------+
# |broker_id|             city|        broker_type|       fund_category|email_opened|webex_meet|sales_call|firm_sales|global_sales|
# +---------+-----------------+-------------------+--------------------+------------+----------+----------+----------+------------+
# |   BRXX-1|   PLANTATION, FL|Inter-dealer broker|Emerging-Markets ...|        NULL|      NULL|      NULL|    174.62|      174.62|
# |   BRXX-1|     BRANFORD, CT|Inter-dealer broker|           Utilities|        NULL|      NULL|      NULL|         0|           0|
# |   BRXX-1|    JONESBORO, GA|Inter-dealer broker|Intermediate Gove...|        NULL|      NULL|      NULL|         0|           0|
# |   BRXX-2|       VIENNA, VA|Inter-dealer broker|Intermediate Gove...|           Y|      NULL|      NULL|         0|       30709|
# ...

# %%
data[["Car_Name","Year"]].show(7)   # selected columns # like pandas code
# Out:
# +-------------+----+
# |     Car_Name|Year|
# +-------------+----+
# |         ritz|2014|
# |          sx4|2013|
# |         ciaz|2017|
# |      wagon r|2011|
# |        swift|2014|
# |vitara brezza|2018|
# |         ciaz|2015|
# +-------------+----+
# only showing top 7 rows

# %%
data.select("Car_Name", "Year").show(6)  # most preferred one
# Out:
# +-------------+----+
# |     Car_Name|Year|
# +-------------+----+
# |         ritz|2014|
# |          sx4|2013|
# |         ciaz|2017|
# |      wagon r|2011|
# |        swift|2014|
# |vitara brezza|2018|
# +-------------+----+
# only showing top 6 rows

# %%
data.select("*").show(5) # to see all columns in a table
# Out:
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |    ritz|2014|         3.35|         5.59|     27000|   Petrol|     Dealer|      Manual|1st Owner|
# |     sx4|2013|         4.75|         9.54|     43000|   Diesel|     Dealer|      Manual|1st Owner|
# |    ciaz|2017|         7.25|         9.85|      6900|   Petrol|     Dealer|      Manual|1st Owner|
# | wagon r|2011|         2.85|         4.15|      5200|   Petrol|     Dealer|      Manual|1st Owner|
# |   swift|2014|          4.6|         6.87|     42450|   Diesel|     Dealer|      Manual|2nd Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# only showing top 5 rows

# %%
#filtering the column
data.select("*").filter(col("Fuel_Type") == 'Petrol').show(6) # if this error occurs import pyspark sql
# Out:
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |    ritz|2014|         3.35|         5.59|     27000|   Petrol|     Dealer|      Manual|1st Owner|
# |    ciaz|2017|         7.25|         9.85|      6900|   Petrol|     Dealer|      Manual|1st Owner|
# | wagon r|2011|         2.85|         4.15|      5200|   Petrol|     Dealer|      Manual|1st Owner|
# |    ciaz|2015|         6.75|         8.12|     18796|   Petrol|     Dealer|      Manual|2nd Owner|
# |alto 800|2017|         2.85|          3.6|      2135|   Petrol|     Dealer|      Manual|2nd Owner|
# |    ciaz|2015|          7.5|         9.94|     15000|   Petrol|     Dealer|   Automatic|2nd Owner|
# ...

# %%
data.select("*").filter(col("Fuel_Type") == 'Petrol').show(6)
# Out:
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |    ritz|2014|         3.35|         5.59|     27000|   Petrol|     Dealer|      Manual|1st Owner|
# |    ciaz|2017|         7.25|         9.85|      6900|   Petrol|     Dealer|      Manual|1st Owner|
# | wagon r|2011|         2.85|         4.15|      5200|   Petrol|     Dealer|      Manual|1st Owner|
# |    ciaz|2015|         6.75|         8.12|     18796|   Petrol|     Dealer|      Manual|2nd Owner|
# |alto 800|2017|         2.85|          3.6|      2135|   Petrol|     Dealer|      Manual|2nd Owner|
# |    ciaz|2015|          7.5|         9.94|     15000|   Petrol|     Dealer|   Automatic|2nd Owner|
# ...

# %%
data.select("Car_Name" , "Year","Selling_Price" ,"Present_Price").filter(col("Fuel_Type") == 'Petrol').show(5)
# to get selected columns
# Out:
# +--------+----+-------------+-------------+
# |Car_Name|Year|Selling_Price|Present_Price|
# +--------+----+-------------+-------------+
# |    ritz|2014|         3.35|         5.59|
# |    ciaz|2017|         7.25|         9.85|
# | wagon r|2011|         2.85|         4.15|
# |    ciaz|2015|         6.75|         8.12|
# |alto 800|2017|         2.85|          3.6|
# +--------+----+-------------+-------------+
# only showing top 5 rows

# %%
data.select("*").filter((col("Fuel_Type") == 'Petrol') & (col("Transmission") == 'Automatic')) .show(5)
# Out:
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |    ciaz|2015|          7.5|         9.94|     15000|   Petrol|     Dealer|   Automatic|2nd Owner|
# |     sx4|2011|          4.4|         8.01|     50000|   Petrol|     Dealer|   Automatic|1st Owner|
# |  baleno|2016|         5.85|         7.87|     24524|   Petrol|     Dealer|   Automatic|1st Owner|
# |    ciaz|2014|          7.5|        12.04|     15000|   Petrol|     Dealer|   Automatic|1st Owner|
# |    ciaz|2017|         7.75|         9.29|     37000|   Petrol|     Dealer|   Automatic|1st Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# only showing top 5 rows

# %%
data.select("Car_Name" , "Year").filter((col("Fuel_Type") == 'Petrol') & (col("Transmission") == 'Automatic')) .show(5)
# Out:
# +--------+----+
# |Car_Name|Year|
# +--------+----+
# |    ciaz|2015|
# |     sx4|2011|
# |  baleno|2016|
# |    ciaz|2014|
# |    ciaz|2017|
# +--------+----+
# only showing top 5 rows

# %%
# count for every year

# %%
data.select("*").filter(col("Year") == 2015).show(5)
# Out:
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |    ciaz|2015|         6.75|         8.12|     18796|   Petrol|     Dealer|      Manual|2nd Owner|
# | s cross|2015|          6.5|         8.61|     33429|   Diesel|     Dealer|      Manual|2nd Owner|
# |    ciaz|2015|         7.45|         8.92|     42367|   Diesel|     Dealer|      Manual|2nd Owner|
# |    ciaz|2015|         6.85|        10.38|     51000|   Diesel|     Dealer|      Manual|2nd Owner|
# |    ciaz|2015|          7.5|         9.94|     15000|   Petrol|     Dealer|   Automatic|2nd Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# only showing top 5 rows

# %%
data.select("*").filter(col("Year") == 2017).show(5)
# Out:
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |    ciaz|2017|         7.25|         9.85|      6900|   Petrol|     Dealer|      Manual|1st Owner|
# |alto 800|2017|         2.85|          3.6|      2135|   Petrol|     Dealer|      Manual|2nd Owner|
# |   ignis|2017|          4.9|         5.71|      2400|   Petrol|     Dealer|      Manual|1st Owner|
# |   swift|2017|          6.0|         6.49|     16200|   Petrol| Individual|      Manual|1st Owner|
# |    ciaz|2017|         7.75|         9.29|     37000|   Petrol|     Dealer|   Automatic|1st Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# only showing top 5 rows

# %%
data.select("*").filter(col("Year") == 2017).count()
# Out:
# 35

# %%
data.groupby("Year").count().show()
# Out:
# +----+-----+
# |Year|count|
# +----+-----+
# |2003|    2|
# |2007|    2|
# |2018|    1|
# |2015|   61|
# |2006|    4|
# |2013|   33|
# |2014|   38|
# |2004|    1|
# |2012|   23|
# |2009|    6|
# |2016|   50|
# |2005|    4|
# |2010|   15|
# |2011|   19|
# |2008|    7|
# |2017|   35|
# +----+-----+

# %%
data.select("Year").groupby("Year").count().show()
# Out:
# +----+-----+
# |Year|count|
# +----+-----+
# |2003|    2|
# |2007|    2|
# |2018|    1|
# |2015|   61|
# |2006|    4|
# |2013|   33|
# |2014|   38|
# |2004|    1|
# |2012|   23|
# |2009|    6|
# |2016|   50|
# |2005|    4|
# |2010|   15|
# |2011|   19|
# |2008|    7|
# |2017|   35|
# +----+-----+

# %%
# before writing sparksql create temp view 

data.createOrReplaceTempView("Car_Tb")   # pyspark sql

# %%
spark.sql("select * from Car_Tb").show(5)
# Out:
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |Car_Name|Year|Selling_Price|Present_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Car_Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# |    ritz|2014|         3.35|         5.59|     27000|   Petrol|     Dealer|      Manual|1st Owner|
# |     sx4|2013|         4.75|         9.54|     43000|   Diesel|     Dealer|      Manual|1st Owner|
# |    ciaz|2017|         7.25|         9.85|      6900|   Petrol|     Dealer|      Manual|1st Owner|
# | wagon r|2011|         2.85|         4.15|      5200|   Petrol|     Dealer|      Manual|1st Owner|
# |   swift|2014|          4.6|         6.87|     42450|   Diesel|     Dealer|      Manual|2nd Owner|
# +--------+----+-------------+-------------+----------+---------+-----------+------------+---------+
# only showing top 5 rows

# %%
spark.sql("select Year, count(*) as total_cars from Car_Tb group by Year order by Year").show()
# Out:
# +----+----------+
# |Year|total_cars|
# +----+----------+
# |2003|         2|
# |2004|         1|
# |2005|         4|
# |2006|         4|
# |2007|         2|
# |2008|         7|
# |2009|         6|
# |2010|        15|
# |2011|        19|
# |2012|        23|
# |2013|        33|
# |2014|        38|
# |2015|        61|
# |2016|        50|
# |2017|        35|
# |2018|         1|
# +----+----------+
