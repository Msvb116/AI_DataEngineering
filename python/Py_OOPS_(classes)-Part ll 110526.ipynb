# %%
class latest_bmi:
    def __init__(self,height,weight):
        self.weight = weight
        self.height = height
    def calculate_bmi(self):
        return self.weight / (self.height * 0.01) ** 2
    def height_in_mts(self):
        return self.height * 0.01

# %%
# here no need to assign the latest_bmi to one variable directly pass values 
# Avoiding one step
# here we dont call as function inside class it is call as method
# in oops first method is initilisation needs  to write
# init 1st value is self and all should be in order

# %%
# This is the Normal function used to calculate BMI
# by using Normal function how many functions are there and whta functions can we use it 
def calculate_bmi_normal(w,h):
    bmi = w/(h * 0.01)**2
    return bmi

# %%
calculate_bmi_normal(42,170)
# Out:
# 14.532871972318341

# %%
def calculate_health_parameters(age, ht, wt , fasting_glucose, SpoCo2, BP, PR, BT , CL):
    ..
    ..
    ..
    ..(logic)
    ..
    ..
    return 
# when you writing same logic in class we dont need to pass paramets we can pass self only
# self will contain every thing i.e,age, ht, wt , fasting_glucose, SpoCo2, BP, PR, BT , CL 
# because we write method called initilization
# self will have the values at that instance , which value is going to execute

# %%
class latest_bmi:
    def __init__(self,height,weight,age,spco2,bp,pr):
        self.weight = weight
        self.height = height
        self.age =age
        self.spco2 = spco2
        self.bp = bp
        self.pr = pr
    def calculate_bmi(self):
        return self.weight / (self.height * 0.01) ** 2
    def height_in_mts(self):
        return self.height * 0.01

# %%
p1 = latest_bmi(70,156)  # self will have p1 data --> 70 & 156 (instance)

# %%
p1.calculate_bmi()
# Out:
# 318.3673469387754

# %%
p1.height_in_mts()
# Out:
# 0.7000000000000001

# %%
p2 = latest_bmi(66,167)

# %%
p2.calculate_bmi()
# Out:
# 383.3792470156106

# %%
p2.height_in_mts()
# Out:
# 0.66
