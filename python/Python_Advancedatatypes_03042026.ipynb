# %%
# Data types 

#int / str / float / bool

# advance data types 

# list / tuple / dict

# %%
# list
# list are collection of elements
# lists are enclosed in []
# lists are mutable (changable , once u creacted , always can change it )

# %%
a = "vinay"
b = 28
c = "Bangalore"
d = 789461237
e = "msvb@gmail.com"

# %%
f = "ravi"
g = "29"
h = "HYD"
i = 7894561230
j = "gfd@gmail.com"

# %%
# for every element we need to define a variable to overcome this we are using this List
# for 1 student = 5 variables
# for 90 students = 90* 5 = 450 variables

# %%
s = ["santosh", 32 ,"Bangalore" , 7894561230 , "msvb.k@gmail.com"]

# %%
v = ["vinay" , 29 , "Bnagalore", 789561230, "asdfgh@gmail.com" ]

# %%
type(s)  # ------> list
# Out:
# list

# %%
s
# Out:
# ['santosh', 32, 'Bangalore', 7894561230, 'msvb.k@gmail.com']

# %%
print(s)
# Out:
# ['santosh', 32, 'Bangalore', 7894561230, 'msvb.k@gmail.com']

# %%
v
# Out:
# ['vinay', 29, 'Bnagalore', 789561230, 'asdfgh@gmail.com']

# %%
print(v)
# Out:
# ['vinay', 29, 'Bnagalore', 789561230, 'asdfgh@gmail.com']

# %%
v[0]
# Out:
# 'vinay'

# %%
v[4]
# Out:
# 'asdfgh@gmail.com'

# %%
v[0:3]
# Out:
# ['vinay', 29, 'Bnagalore']

# %%
v[2:4]
# Out:
# ['Bnagalore', 789561230]

# %%
v[0:]
# Out:
# ['vinay', 29, 'Bnagalore', 789561230, 'asdfgh@gmail.com']

# %%
s = ["santosh", 32 ,"Bangalore" , 7894561230 , "msvb.k@gmail.com"]

# %%
s[2] = "Hyderabad"

# %%
s
# Out:
# ['santosh', 32, 'Hyderabad', 7894561230, 'msvb.k@gmail.com']

# %%
s[5] = "student"   # cannot add the index concept here

# %%
s.append("student")

# %%
s
# Out:
# ['santosh', 32, 'Hyderabad', 7894561230, 'msvb.k@gmail.com', 'student']

# %%
m =['msd' , 28]

# %%
m
# Out:
# ['msd', 28]

# %%
m.append(79456123)

# %%
m
# Out:
# ['msd', 'KSR', 79456123]

# %%
m.insert('KSR')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 m.insert('KSR')
#
# TypeError: insert expected 2 arguments, got 1

# %%
m.insert(1,'KSR')

# %%
m
# Out:
# ['msd', 'KSR', 'KSR', 79456123]

# %%
m.insert(3,"student")   # to add in certain position

# %%
m
# Out:
# ['msd', 'KSR', 'KSR', 'student', 79456123]

# %%
m.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 m.remove()
#
# TypeError: list.remove() takes exactly one argument (0 given)

# %%
m.remove(28) # have to specify the value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 m.remove(28) # have to specify the value
#
# ValueError: list.remove(x): x not in list

# %%
m
# Out:
# ['msd', 'KSR', 'KSR', 'student', 79456123]

# %%
m.pop()  # will remove the last value
# Out:
# 79456123

# %%
m
# Out:
# ['msd', 'KSR', 'KSR', 'student']

# %%
m.pop()
# Out:
# 'student'

# %%
m
# Out:
# ['msd', 'KSR', 'KSR']

# %%
m.pop()
# Out:
# 'KSR'

# %%
m
# Out:
# ['msd', 'KSR']

# %%
s
# Out:
# ['santosh', 32, 'Hyderabad', 7894561230, 'msvb.k@gmail.com', 'student']

# %%
s.pop(32)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 s.pop(32)
#
# IndexError: pop index out of range

# %%
s.pop(2)
# Out:
# 'Hyderabad'

# %%
s
# Out:
# ['santosh', 32, 7894561230, 'msvb.k@gmail.com', 'student']

# %%
s.clear()

# %%
s
# Out:
# []

# %%
a = [1,4,2,4,5,6,7,0]

# %%
a
# Out:
# [1, 4, 2, 4, 5, 6, 7, 0]

# %%
a.reverse()  # to reverse the values in list

# %%
a
# Out:
# [0, 7, 6, 5, 4, 2, 4, 1]

# %%
s = ["santosh", 32 ,"Bangalore" , 7894561230 , "msvb.k@gmail.com"]

# %%
s.reverse()  # to reverse the values in list

# %%
s
# Out:
# ['msvb.k@gmail.com', 7894561230, 'Bangalore', 32, 'santosh']

# %%
a = [1,5,7,9,5,3]

# %%
a.sort()  # to arrange in order asc to desc

# %%
a
# Out:
# [1, 3, 5, 5, 7, 9]

# %%
s = ["santosh", 32 ,"Bangalore" , 7894561230 , "msvb.k@gmail.com"]

# %%
s.sort()   #  here sort will not be able to do  bcoz of all
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 s.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
a =["guntur" , "Hyderabad" ,"bombay"]  # sort done by alphabatecically

# %%
a.sort()

# %%
a
# Out:
# ['Hyderabad', 'bombay', 'guntur']

# %%
a =[1,2,4,5,6]

# %%
b = [7,8,9,6,4]

# %%
a.extend(b) # to merge the two list values

# %%
a
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9, 6, 4]

# %%
a =["guntur" , "Hyderabad" ,"bombay"]

# %%
a
# Out:
# ['guntur', 'Hyderabad', 'bombay']

# %%
b = a.copy() # too take copy of a list

# %%
b
# Out:
# ['guntur', 'Hyderabad', 'bombay']

# %%
 a= [1,2,6,1,4,6]   # to find the count of values in list

# %%
a.count(1)
# Out:
# 2

# %%
a.count(6)
# Out:
# 2
