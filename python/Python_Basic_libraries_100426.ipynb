# %% [markdown]
# ### Libraries
# ### libraries are set of functions already implement / exists W eare free to use

# %%
import math as m     # mathematical functions X
import scipy as s    # scientific Python      X
from scipy import constants as c
import pandas as pd   # DE/DS/DA library  (** very widely used in realtime **)
import warnings
import time

# %%
math.factorial(5)              # 5 factorial = 5*4*3*2*1
# Out:
# 120

# %%
m.factorial(6)
# Out:
# 720

# %%
m.pow(3,2)
# Out:
# 9.0

# %%
m.pow(4,2)
# Out:
# 16.0

# %%
m.lcm(2,4,2)
# Out:
# 4

# %%
m.gcd(5,10)
# Out:
# 5

# %%
m.cos(90)
# Out:
# -0.4480736161291701

# %%
m.exp(5)
# Out:
# 148.4131591025766

# %%
m.sqrt(36)
# Out:
# 6.0

# %%
c.gravitational_constant
# Out:
# 6.6743e-11

# %%
c.speed_of_light
# Out:
# 299792458.0

# %%
c.day
# Out:
# 86400.0
