# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello welcome to Data Engineering Course..!")
# Out:
# Hello welcome to Data Engineering Course..!

# %%
a = 4
b = 6 
c =a+b
print(c)
# Out:
# 10

# %%
Print("Hello World!")  # wont work becoz it is casesensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Print("Hello World!")
#
# NameError: name 'Print' is not defined

# %%
a = 25   # assign value to variable
print(a)
# Out:
# 25

# %%
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(A)
#
# NameError: name 'A' is not defined
