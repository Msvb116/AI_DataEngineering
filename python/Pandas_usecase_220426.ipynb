# %%
import pandas as pd

# %%
emp = pd.read_csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\SQL\\Data_Sets\\Emp1.csv" , encoding = "ISO-8859-1")

# %%
training = pd.read_csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\SQL\\Data_Sets\\Training1.csv" , encoding = "ISO-8859-1")

# %%
emp.head(10)
# Out:
#    EmployeeID  ManagerID             Title MaritalStatus Gender  \
# 0           1         16    Gustavo Achong             M      M
# 1           2          6    Catherine Abel             S      M
# 2           3         12   Kim Abercrombie             M      M
# 3           4          3  Humberto Acevedo             S      M
# 4           5        263    Pilar Ackerman             M      M
# 5           6        109     Frances Adams             S      M
# 6           7         21    Margaret Smith             S      F
# 7           8        185       Carla Adams             M      F
# 8           9          3         Jay Adams             M      F
# 9          10        185      Ronald Adina             S      M
#
#            HireDate            Dept    JobGrade
# 0  02-02-2013 00:00           Sales       Admin
# 1  31-08-2013 00:00           Sales  Management
# 2  16-06-2014 00:00         Finance       Admin
# 3  10-07-2014 00:00       Logistics       Admin
# ...

# %%
training.head(5)
# Out:
#    Start Date  Course Code             Course Name  Employee_ID  Cost  \
# 0  18-09-2015            1  Communication Workshop            1  1300
# 1  18-09-2015            1  Communication Workshop            4  1300
# 2  18-09-2015            1  Communication Workshop           25  1300
# 3  18-09-2015            1  Communication Workshop           33  1300
# 4  18-09-2015            1  Communication Workshop           44  1300
#
#                 Supplier
# 0  Communication Experts
# 1  Communication Experts
# 2  Communication Experts
# 3  Communication Experts
# 4  Communication Experts

# %%
# I want to see which emp had spent max amount for training (cost)

# %%
training.groupby("Employee_ID")[["Cost"]].sum().reset_index().sort_values("Cost" , ascending = False).head(5)
# Out:
#     Employee_ID   Cost
# 11           12  47850
# 13           14  38150
# 27           28  36000
# 5             6  31500
# 20           21  29400

# %%
# joins with groupby

# %%
result = pd.merge(emp, training, left_on = "EmployeeID", right_on = "Employee_ID", how = "inner")

# %%
result.shape
# Out:
# (419, 14)

# %%
result.columns
# Out:
# Index(['EmployeeID', 'ManagerID', 'Title', 'MaritalStatus', 'Gender',
#        'HireDate', 'Dept', 'JobGrade', 'Start Date', 'Course Code',
#        'Course Name', 'Employee_ID', 'Cost', 'Supplier'],
#       dtype='object')

# %%
result.groupby("Title")[["Cost"]].sum().reset_index().sort_values("Cost" , ascending = False).head(10)
# Out:
#                Title   Cost
# 16     James Aguilar  47850
# 10  François Ferrier  38150
# 4      Cecil Allison  36000
# 9      Frances Adams  31500
# 11  Gregory Alderson  29400
# 22    Kyley Arbelaez  29300
# 25    Margaret Smith  28300
# 28    Maxwell Amland  27450
# 19         John Ault  25500
# 21         Kim Akers  25050

# %%
pd.merge(emp, training, left_on = "EmployeeID", right_on = "Employee_ID", how = "inner") \
    .groupby("Title")[["Cost"]].sum().reset_index() \
    .query("Cost > 30000") \
    .sort_values("Cost" , ascending = False)
# Out:
#                Title   Cost
# 16     James Aguilar  47850
# 10  François Ferrier  38150
# 4      Cecil Allison  36000
# 9      Frances Adams  31500
