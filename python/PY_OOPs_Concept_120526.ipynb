# %%
# key concepts in oops
# 1) Class      ****Imp****
# 2) Inheritance
# 3) Encapsulation
# 4) Abstraction
# 5) Polymorphism

# %%
# class --> blueprint , variables & Methods , user defined structure / data type
# Inheritance --> It is the capability of one class to derive or inherit the properties of another class
# Encapsulation--> in which i am wrapping all related variables / methods in 1 unit
# Abstraction --> (abstarct class) it hides unnecessary info / code to users (sensitive info should be hidden)
# Polymorphism --> Allows you to write code that can work with objects of diff classes (Poly -many))
