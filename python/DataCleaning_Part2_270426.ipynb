# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\EmployeeDataToClean.csv" , encoding = "ISO-8859-1")

# %%
data.shape
# Out:
# (50, 14)

# %%
data.head(3)
# Out:
#    EmployeeID  NationalIDNumber                 LoginID            Title  \
# 0           1          14417807    adventure-works\guy1   Gustavo Achong
# 1           2         253022876  adventure-works\kevin0   Catherine Abel
# 2           3         509647174                     NaN  Kim Abercrombie
#
#     PhoneNumber         BirthDate MaritalStatus Gender          HireDate  \
# 0  9.257522e+09  21-02-1986 00:00             M      M  02-02-2013 00:00
# 1  9.235868e+09  12-03-1991 00:00             S      M  31-08-2013 00:00
# 2  9.416422e+09  21-09-1978 00:00             M      M  16-06-2014 00:00
#
#       Dept  Salary   Job Grade  CurrentFlag  \
# 0    Sales  2295.0       Admin           -1
# 1    Sales   962.0  Management           -1
# 2  Finance  4006.0       Admin           -1
#
#                                   rowguid
# 0  {AAE1D04A-C237-4974-B4D5-935247737718}
# 1  {1B480240-95C0-410F-A717-EB29943C8886}
# 2  {9BBBFB2C-EFBB-4217-9AB7-F97689328841}

# %%
list(data.columns)
# Out:
# ['EmployeeID',
#  'NationalIDNumber',
#  'LoginID',
#  'Title',
#  'PhoneNumber',
#  'BirthDate',
#  'MaritalStatus',
#  'Gender',
#  'HireDate',
#  'Dept',
#  'Salary',
#  'Job Grade',
#  'CurrentFlag',
#  'rowguid']

# %%
data.isna().sum()
# Out:
# EmployeeID           0
# NationalIDNumber     0
# LoginID             37
# Title                0
# PhoneNumber          7
# BirthDate            0
# MaritalStatus        0
# Gender               0
# HireDate             0
# Dept                 0
# Salary               6
# Job Grade            0
# CurrentFlag          0
# rowguid              0
# dtype: int64

# %%
(data.isna().sum() / data.shape[0]) * 100
# Out:
# EmployeeID           0.0
# NationalIDNumber     0.0
# LoginID             74.0
# Title                0.0
# PhoneNumber         14.0
# BirthDate            0.0
# MaritalStatus        0.0
# Gender               0.0
# HireDate             0.0
# Dept                 0.0
# Salary              12.0
# Job Grade            0.0
# CurrentFlag          0.0
# rowguid              0.0
# dtype: float64

# %%
# if the column has more than 70 % we will drop the column

# %%
# drop the column LoginID   -- Here we cannot impute the column
# in Phone number need to convert from 9.257522e+09 ( current data )
# 987561230 ---> Need to share 
# 987XXXX30 ---> Need to add masking

# %%
# Data Cleaning Steps:
# 1)  drop the column LoginID  --  column has more than 70 % we will drop the column
# 2)  impute phone number (data Correction, also masking is needed)
# 3)  NationalIDNumber is not useful for reporting , unique records could be identified via emp_id, so this could be eleminated)
# 4) Drop the current flag (because you have only one unique value  -> useless)
# 5) rowguiid can give me unique empcount, since we have already employeecount (emp_id) we can discard this

# %%
data['CurrentFlag'].unique()
# Out:
# array([-1])

# %%
data['rowguid'].nunique()
# Out:
# 50

# %%
data.dtypes
# Out:
# EmployeeID            int64
# NationalIDNumber      int64
# LoginID              object
# Title                object
# PhoneNumber         float64
# BirthDate            object
# MaritalStatus        object
# Gender               object
# HireDate             object
# Dept                 object
# Salary              float64
# Job Grade            object
# CurrentFlag           int64
# rowguid              object
# dtype: object

# %%
# Datasteps implementation

# %%
data['PhoneNumber'] = data['PhoneNumber'].fillna(0000000000)

# data['PhoneNumber'] = data['PhoneNumber'].astype(int) # int casting error due to lot of NaN values are there 

data['PhoneNumber'] = data['PhoneNumber'].astype("object")  # here decimal values will come to overcome this we use int64 thpe
data['PhoneNumber'] = data['PhoneNumber'].astype("int64")   # here warnings are coming to overcome this keep the import warnings syntax

# %%
data.head(5)
# Out:
#    EmployeeID  NationalIDNumber                 LoginID             Title  \
# 0           1          14417807    adventure-works\guy1    Gustavo Achong
# 1           2         253022876  adventure-works\kevin0    Catherine Abel
# 2           3         509647174                     NaN   Kim Abercrombie
# 3           4         112457891                     NaN  Humberto Acevedo
# 4           5         480168528                     NaN    Pilar Ackerman
#
#    PhoneNumber         BirthDate MaritalStatus Gender          HireDate  \
# 0   9257522351  21-02-1986 00:00             M      M  02-02-2013 00:00
# 1   9235868360  12-03-1991 00:00             S      M  31-08-2013 00:00
# 2   9416421559  21-09-1978 00:00             M      M  16-06-2014 00:00
# 3   8800042425  01-11-1978 00:00             S      M  10-07-2014 00:00
# 4            0  07-06-1963 00:00             M      M  16-07-2014 00:00
#
#              Dept  Salary   Job Grade  CurrentFlag  \
# 0           Sales  2295.0       Admin           -1
# 1           Sales   962.0  Management           -1
# 2         Finance  4006.0       Admin           -1
# 3       Logistics  4547.0       Admin           -1
# 4  Human Resource  1932.0       Admin           -1
#
#                                   rowguid
# 0  {AAE1D04A-C237-4974-B4D5-935247737718}
# 1  {1B480240-95C0-410F-A717-EB29943C8886}
# 2  {9BBBFB2C-EFBB-4217-9AB7-F97689328841}
# 3  {59747955-87B8-443F-8ED4-F8AD3AFDF3A9}
# 4  {1D955171-E773-4FAD-8382-40FD898D5D4D}

# %%
# mask the phone number 9257522351 --> 925XXXXX51

# %%
a = "7075757415"

# %%
a[0:3]
# Out:
# '707'

# %%
a[-2:]
# Out:
# '15'

# %%
a[0:3] + "xxxx" + a[-2:]    # to create maskingin python
# Out:
# '707xxxx15'

# %%
def phn_masking(a):
    a = str(a)
    if a == '0':
        return "XXXXXXXXXX"
    else:
        result = a[0:3] + "XXXX" + a[-2:]
    return result

# %%
def f_materialstatus(a):
    if a == 'M':
        return 1
    else:
        return 0

# %%
data["Is_Married"] = data['MaritalStatus'].apply(f_materialstatus)
data["Is_Male"] = data['Gender'].apply(f_genderstatus)

# %%
def f_genderstatus(a):
    if a == 'M':
        return 1
    else:
        return 0

# %%
phn_masking(7075757415)
# Out:
# '707XXXX15'

# %%
phn_masking(0)
# Out:
# 'XXXXXXXXXX'

# %%
data['PhoneNumber'] = data['PhoneNumber'].apply(phn_masking)

# %%
data.head(5)
# Out:
#    EmployeeID  NationalIDNumber                 LoginID             Title  \
# 0           1          14417807    adventure-works\guy1    Gustavo Achong
# 1           2         253022876  adventure-works\kevin0    Catherine Abel
# 2           3         509647174                     NaN   Kim Abercrombie
# 3           4         112457891                     NaN  Humberto Acevedo
# 4           5         480168528                     NaN    Pilar Ackerman
#
#   PhoneNumber         BirthDate MaritalStatus Gender          HireDate  \
# 0   925XXXX51  21-02-1986 00:00             M      M  02-02-2013 00:00
# 1   923XXXX60  12-03-1991 00:00             S      M  31-08-2013 00:00
# 2   941XXXX59  21-09-1978 00:00             M      M  16-06-2014 00:00
# 3   880XXXX25  01-11-1978 00:00             S      M  10-07-2014 00:00
# 4  XXXXXXXXXX  07-06-1963 00:00             M      M  16-07-2014 00:00
#
#              Dept  Salary   Job Grade  CurrentFlag  \
# 0           Sales  2295.0       Admin           -1
# 1           Sales   962.0  Management           -1
# 2         Finance  4006.0       Admin           -1
# 3       Logistics  4547.0       Admin           -1
# 4  Human Resource  1932.0       Admin           -1
#
#                                   rowguid  Is_Married  Is_Male
# 0  {AAE1D04A-C237-4974-B4D5-935247737718}           1        1
# 1  {1B480240-95C0-410F-A717-EB29943C8886}           0        1
# 2  {9BBBFB2C-EFBB-4217-9AB7-F97689328841}           1        1
# 3  {59747955-87B8-443F-8ED4-F8AD3AFDF3A9}           0        1
# 4  {1D955171-E773-4FAD-8382-40FD898D5D4D}           1        1

# %%
data.columns
# Out:
# Index(['EmployeeID', 'NationalIDNumber', 'LoginID', 'Title', 'PhoneNumber',
#        'BirthDate', 'MaritalStatus', 'Gender', 'HireDate', 'Dept', 'Salary',
#        'Job Grade', 'CurrentFlag', 'rowguid', 'Is_Married', 'Is_Male'],
#       dtype='object')

# %%
# drop columns NationalIDNumber / LoginID / MaritalStatus / Gender / CurrentFlag / rowguid

# %%
data.shape
# Out:
# (50, 16)

# %%
data.drop("NationalIDNumber")  # will not work because we have to specify the axis

# %%
data = data.drop("NationalIDNumber" , axis = 1)

# %%
data.shape
# Out:
# (50, 15)

# %%
data = data.drop(["LoginID","MaritalStatus", "Gender", "CurrentFlag" , "rowguid"] , axis = 1)

# %%
data.shape
# Out:
# (50, 10)

# %%
data.head(5)
# Out:
#    EmployeeID             Title PhoneNumber         BirthDate  \
# 0           1    Gustavo Achong   925XXXX51  21-02-1986 00:00
# 1           2    Catherine Abel   923XXXX60  12-03-1991 00:00
# 2           3   Kim Abercrombie   941XXXX59  21-09-1978 00:00
# 3           4  Humberto Acevedo   880XXXX25  01-11-1978 00:00
# 4           5    Pilar Ackerman  XXXXXXXXXX  07-06-1963 00:00
#
#            HireDate            Dept  Salary   Job Grade  Is_Married  Is_Male
# 0  02-02-2013 00:00           Sales  2295.0       Admin           1        1
# 1  31-08-2013 00:00           Sales   962.0  Management           0        1
# 2  16-06-2014 00:00         Finance  4006.0       Admin           1        1
# 3  10-07-2014 00:00       Logistics  4547.0       Admin           0        1
# 4  16-07-2014 00:00  Human Resource  1932.0       Admin           1        1

# %%
# in python we dont have direct date datatype need to import time

# %%
data.dtypes
# Out:
# EmployeeID       int64
# Title           object
# PhoneNumber     object
# BirthDate       object
# HireDate        object
# Dept            object
# Salary         float64
# Job Grade       object
# Is_Married       int64
# Is_Male          int64
# dtype: object

# %%
b = "Python"

# %%
b[1]
# Out:
# 'y'

# %%
b[5]
# Out:
# 'n'

# %%
b[0:3]
# Out:
# 'Pyt'

# %%
b[2:6]
# Out:
# 'thon'

# %%
b[2:]
# Out:
# 'thon'

# %%
c = "Data Engineering is Interesting Subject"

# %%
c[5:]
# Out:
# 'Engineering is Interesting Subject'

# %%
b = "Python"

# %%
b[-2:]
# Out:
# 'on'

# %%
b[-4:]
# Out:
# 'thon'
