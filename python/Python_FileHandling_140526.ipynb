# %%
# file handling in python allows you to work with computer/ desktops/ server files / log files.
# It provides built in functions

# %%
file = open("C:\\Users\\DELL\\Desktop\\Py.txt" , "r")   # r stands for Reading the file
content = file.read()
print(content)
# Out:
# The file is writing by the pythonThe file is appended by the python

# %%
file = open("C:\\Users\\DELL\\Desktop\\Py.txt" , "w")   # w stands for write the file
file.write("The file is writing by the python")
file.close()

# %%
file = open("C:\\Users\\DELL\\Desktop\\Py.txt" , "a")   # a stands for append the file
file.write("The file is appended by the python")
file.close()

# %%
# In Real time --> In app , log files will be generated(file handling will be helpful to read/write/move/copy files into diff locations

# %%
import platform as p
import os # os operating system
import socket
import shutil as s # shell utility

# %%
p.system()
# Out:
# 'Windows'

# %%
p.node()
# Out:
# 'Msvb'

# %%
p.uname()
# Out:
# uname_result(system='Windows', node='Msvb', release='11', version='10.0.26200', machine='AMD64')

# %%
p.processor()
# Out:
# 'Intel64 Family 6 Model 142 Stepping 10, GenuineIntel'

# %%
p.java_ver()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7576\1820199562.py:1: DeprecationWarning: 'java_ver' is deprecated and slated for removal in Python 3.15
#   p.java_ver()
# ('', '', ('', '', ''), ('', '', ''))

# %%
p.python_version()
# Out:
# '3.13.9'

# %%
os.stat_result
# Out:
# os.stat_result

# %%
os.cpu_count()
# Out:
# 8

# %%
# Copying / Moving

# %%
s.copy("C:\\Users\\DELL\\Desktop\\src\\py.txt" , "C:\\Users\\DELL\\Desktop\\tgt")
# Out:
# 'C:\\Users\\DELL\\Desktop\\tgt\\py.txt'

# %%
s.move("C:\\Users\\DELL\\Desktop\\src\\py.txt" , "C:\\Users\\DELL\\Desktop\\tgt")
# Out:
# 'C:\\Users\\DELL\\Desktop\\tgt\\py.txt'

# %%
s.copy2()  # check this

# %%
s.copytree()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 s.copytree()
#
# TypeError: copytree() missing 2 required positional arguments: 'src' and 'dst'

# %%
# socket

# %%
hostname = "www.datavizon.com"
ip_address = socket.gethostbyname(hostname)
print(ip_address)
# Out:
# 54.91.116.162

# %%
hostname = "www.google.com"
ip_address = socket.gethostbyname(hostname)
print(ip_address)
# Out:
# 142.251.150.119

# %%
# Polars library

# %%
# !pip install polars
# Out:
# ...
#    ---------------------------------------- 0.0/828.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/828.7 kB ? eta -:--:--
#    ------------------------------------- -- 786.4/828.7 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 828.7/828.7 kB 3.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/51.8 MB ? eta -:--:--
#     --------------------------------------- 0.8/51.8 MB 4.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.6/51.8 MB 4.3 MB/s eta 0:00:12
#    - -------------------------------------- 2.4/51.8 MB 4.0 MB/s eta 0:00:13
#    -- ------------------------------------- 3.1/51.8 MB 3.9 MB/s eta 0:00:13
#    -- ------------------------------------- 3.7/51.8 MB 3.9 MB/s eta 0:00:13
#    --- ------------------------------------ 3.9/51.8 MB 3.4 MB/s eta 0:00:14
#    --- ------------------------------------ 4.5/51.8 MB 3.1 MB/s eta 0:00:16
# ...

# %%
import polars as po

# %%
po.date
# Out:
# <function polars.functions.as_datatype.date_(year: 'Expr | str | int', month: 'Expr | str | int', day: 'Expr | str | int') -> 'Expr'>

# %%
cust_data = po.read_excel("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\Data_Sets\\Cust_Data.xlsx")

# %%
pip install fastexcel
# Out:
# ...
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.3 MB ? eta -:--:--
#    ------------------------- -------------- 2.1/3.3 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 8.5 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
type(cust_data)
# Out:
# polars.dataframe.frame.DataFrame
