# %%
a = "KSR"
b = 6
c = 4.9

# %%
print(a)
# Out:
# KSR

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# float

# %% [raw]
# # comments  ----> only humans can understand
# # variables
# # variables are place holders , store it and it will be useful for further process
# # variables are case sensitive
# # variables should be single word only
# # variables name can be support only one type of special characters (underscore '_')
# # variable name cannot start with integers
# # variable names cannot be keywords
# # variables are changable (overwrite)

# %%
a = 107                   # ok for me
totstudents = 107         # ok for me
TS = 07                   # ok for me
tot_students = 107        # ok for me
total students = 107      # not ok for me 
total$students = 107      # not ok for me

# %%
_students_ = 107   # allowed
students_ = 107    # allowed
tot_students = 107 # allowed

# %%
print(students_)
# Out:
# 107

# %%
dhoni = "capitain"        #acceptable
_dhoni = "cool capitain"  #acceptable
_dhoni_ = "indian"        #acceptable
M_S_dhoni = "csk cap"     #acceptable
7_dhon7 = "cap"           # not acceptable
M S Dhoni = "crickter"    # not acceptable
7 = "Dhoni"               # not acceptable

# %%
print(a)       # display
# Out:
# KSR

# %%
type(a)         # type
# Out:
# str

# %%
print = 7 # not acceptable
type = 56 # not acceptable

# %%
a = "python"
b = 108
c = "10:15"
d = "9:30"

# %%
# Assign the variable to the values 
today_class = "Python"
students = 108
classstart = "10:15"
classend = "9:30"

# %%
print(today_class)
# Out:
# Python
