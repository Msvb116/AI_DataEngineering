# %%
a = 'ksr'  # string
b = 5      # int
c = 1.8    # float
d = True   # boolean

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# float

# %%
type(d)
# Out:
# bool

# %% [markdown]
# ### data types --> string / float / integer / boolean

# %%
a = "ksr data vision"
b = "bangalore"
c = 'python'
 ## this wont work
d = 'ican't understand'

# %%
# in python index always starts from 0
# for accessing element/char  --- use index -->[] ex: [0]

# %%
a = 'python'

# %%
a[0]
# Out:
# 'p'

# %%
a[6]

# %%
b = "KSR DATAVIOSION"

# %%
b[0]
# Out:
# 'K'

# %%
b[3]
# Out:
# ' '

# %%
b[0:2]
# Out:
# 'KS'

# %%
b[0:3]
# Out:
# 'KSR'

# %%
b[4:8]
# Out:
# 'DATA'

# %%
b[0:15]
# Out:
# 'KSR DATAVIOSION'

# %%
b[0:]
# Out:
# 'KSR DATAVIOSION'

# %%
c = "python is interesting" # expected output  interest

# %%
c[10:18]
# Out:
# 'interest'

# %%
d = "KSR is Best Institute"

# %%
d[7:11]
# Out:
# 'Best'

# %%
# indexing'
# to acces element --> [start:end] pls note end position to be added excluding index (add + 1)
#                       step is optional ---Default step is 1

# %%
x = "datavision"   # want to extract word "DATA"

# %%
x[0:4]
# Out:
# 'data'

# %%
x[0:10:1]   # by default it will be one number
# Out:
# 'datavision'

# %%
x[0:10:2] # if we give 2 it will take one letter extra
# Out:
# 'dtvso'

# %%
c = "Hello World!"   # expected output : hlow

# %%
c[0:7:2]
# Out:
# 'HloW'

# %%
a = 'data engineering'  # string

# %%
type(a)
# Out:
# str

# %%
a.upper()  # shift + enter to run
# Out:
# 'DATA ENGINEERING'

# %%
a.lower()
# Out:
# 'data engineering'

# %%
a.islower()
# Out:
# True

# %%
a.isupper()
# Out:
# False

# %%
s = "DaTa VisIoN"

# %%
s.swapcase()  # to swap the cases
# Out:
# 'dAtA vISiOn'

# %%
a = '123'   # to check if it is digits or not

# %%
a.isdigit()
# Out:
# True

# %%
b = 'eight'

# %%
b.isdigit()
# Out:
# False
