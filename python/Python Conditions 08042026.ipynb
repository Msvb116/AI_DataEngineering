# %%
a = 50

# %%
if a > 35:
    print("The student is pass")
# Out:
# The student is pass

# %%
if a > 35:
    print("The student is pass")
else:
    print("The student is fail")
# Out:
# The student is pass

# %%
a = 20

# %%
if a >= 35:
    print("The student is pass")           # only  one condition

# %%
if a >= 35:
    print("The student is pass") 
else:
    print("The student is failed")     # if and else  conditions
# Out:
# The student is failed

# %%
a = 100

# %%
if a == 100:
    print("The student is Outstanding") 
elif a > 90:        # else if  --> elif
    print("The student is Top class") 
elif a >= 80 and a <= 90:
    print("The student is Avg")
elif a >= 50 and a <= 80:
    print("The student is Avg") 
elif a >= 95 and a <= 50:
    print("The student is Avg")
    
    
else:
    print("The student is failed")
                                                                                        # if ,elif and else  conditions
# Out:
# The student is Outstanding

# %%
# in java same req 14 brackets 
# in python --> 0 brackets

# %%
# in java code 
#public class Main {
#    public static void main(String[] args) {
 #       int a = 40; // Example value

 #       if (a >= 35) {
  #          System.out.println("The student is pass");
   #     } else {
    #        System.out.println("The student is failed");
     #   }
  #  }
#} # brackets is the key in Java code

# %%
#In python no need of brackets we follow the indentation method

# %%
if a >= 35:
print("The student is pass")     # this wont work
else:
print("The student is failed")
# Out:
#   Cell In[22], line 2
#     print("The student is pass")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if a >= 35:
    print("The student is pass") 
else:
    print("The student is failed")
# Out:
# The student is failed

# %%
# logical operators

# %%
x = 5
y = 6

# %%
print(x > 5 and x > 6)
# Out:
# False

# %%
print(x == 5 or x > 6)
# Out:
# True

# %%
# bitwise operators

# %%
print( 4 & 5)
# Out:
# 4

# %%
 4 --> 100
 5 --> 101
        ----
        100 --4

# %%
print( 4 | 5)
# Out:
# 5

# %%
 4 --> 100
 5 --> 101
        ----

# %%
# logical gates
0 ---> 000
1 ---> 001
2 ---> 010
3 ---> 011
4 ---> 100
5 ---> 101
6 ---> 110
7 ---> 111
# Out:
#   Cell In[9], line 3
#     1 ---> 001
#            ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
