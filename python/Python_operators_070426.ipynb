# %% [markdown]
# # python operators
# # operators are  symbols or keywords that perform certain operations on variables

# %%
# types of operators 
#1. Arithemetatic 
#2. comparision / relational operators 
#3. logical operators
#4. Bitwise operators

# %%
#1. Arithemetatic

# %%
a = 10
b = 5
c = a + b          # add
d = a -b          # sub
e = a* b         # multip
f = a / b        # divis
g = a // b       # ia also a division  only taking quotient 
h = a ** b      # ** is power
i = a% b         # % is mode

# %%
a + b
# Out:
# 15

# %%
print("sum:",c)
print("sub:",d)
print("multip:",e)
print("div:",f)
print("div2:",g)
print("power:",h)
print("modepercentage:",i)
# Out:
# sum: 15
# sub: 5
# multip: 50
# div: 2.0
# div2: 2
# power: 100000
# modepercentage: 0

# %%
#2. comparision / relational operators

# %%
x = 6
y = 4

# %%
print(x == y)  # double == is comparing the values = is only for assignment
# Out:
# False

# %%
print(x!=y) # not equal
# Out:
# True

# %%
print(x> y) # greaterthan
# Out:
# True

# %%
print (x < y ) # lessthan
# Out:
# False
