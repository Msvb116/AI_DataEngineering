# %%
import pandas as pd

# %% [markdown]
# #### pandas -> library (data manipulation, analysis & cleaning)
# #### pandas -> panel Data (python data analysis)
# #### pandas -> can analyze data , can do calculations ,manipulate, read files (diff sources)

# %%
d1 = {
    "Car_Name" : "BMW",
    "Year" : 2017,
    "Fuel_Type":"Petrol"
}

# %%
d1 = {
    "Car_Name" : ["ritz", "sX4", "ciaz"],
    "Year" : [2017,2013,2014],
    "Fuel_Type":["Petrol" , "Diesel" , "Petrol"]
}

# problem with Dictonary --> Analysis become difficult

# %%
# how to access 2013
d1['Year']
# Out:
# [2017, 2013, 2014]

# %%
d1['Year'][1]
# Out:
# 2013

# %%
# Data type is only applicable inside this library called as pandas

# %%
data = pd.read_csv("C:\\Users\\DELL\\Desktop\\AI_DATA_ENGINEERING\\SQL\\Data_Sets\\Car_Data.csv") # to read complete data file

# %%
data1 = 16
data2 = "KSR"
data3 = 5.6
data4 = [56,16,28]
data5 = ("KSR" , 2019)
data6 = {"Institute":"KSR" , "Founded": 2018}
data = pd.read_csv("C:\\Users\\DELL\\Desktop\\AI DATA_ENGINEERING\\SQL\\Data_Sets\\Car_Data.csv")

# %%
#type(data1)
#type(data2)
#type(data3)
#type(data4)
#type(data5)
#type(data6)
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(3)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Car_Owner
# 0      Dealer       Manual  1st Owner
# 1      Dealer       Manual  1st Owner
# 2      Dealer       Manual  1st Owner

# %%
# dataframe(datatype) --> It is a 2 dimentional table like structure (rows and columns)
#                     --> This dataframe can be relate to spreadsheet/csv/sql

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()  # this is function
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Car_Owner
# 0      Dealer       Manual  1st Owner
# 1      Dealer       Manual  1st Owner
# 2      Dealer       Manual  1st Owner
# 3      Dealer       Manual  1st Owner
# 4      Dealer       Manual  2nd Owner

# %%
data.head(2)  # first 2 records
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Car_Owner
# 0      Dealer       Manual  1st Owner
# 1      Dealer       Manual  1st Owner

# %%
# any functions do open and close brackets

# %%
data.tail(3) # last 3 records
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Car_Owner
# 298      Dealer       Manual  1st Owner
# 299      Dealer       Manual  1st Owner
# 300      Dealer       Manual  1st Owner

# %%
# count of complete records in data set
data.shape   # this is instance it will be total row count and column count
            # result looks like tuple
            # used in documentation purpose
# Out:
# (301, 9)

# %%
data.shape[0]  # only row count
# Out:
# 301

# %%
data.shape[1]  # only column count
# Out:
# 9

# %%
print("The data set has ", data.shape[0], "rows")
# Out:
# The data set has  301 rows

# %%
data.columns  # to get all the column names  This is instance
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Car_Owner'],
#       dtype='object')

# %%
# to find internal datatype of columns
data.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Car_Owner         object
# dtype: object

# %%
data.head(3)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Car_Owner
# 0      Dealer       Manual  1st Owner
# 1      Dealer       Manual  1st Owner
# 2      Dealer       Manual  1st Owner

# %%
data[data['Year'] == 2014].head(5)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# 23  alto k10  2014           2.50           3.46       45280    Petrol
# 32     swift  2014           4.95           7.49       39000    Diesel
# 33    ertiga  2014           6.00           9.95       45000    Diesel
#
#    Seller_Type Transmission  Car_Owner
# 0       Dealer       Manual  1st Owner
# 4       Dealer       Manual  2nd Owner
# 23      Dealer       Manual  1st Owner
# 32      Dealer       Manual  1st Owner
# 33      Dealer       Manual  1st Owner

# %%
data[data['Fuel_Type'] == 'Petrol'].head(5)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 6       ciaz  2015           6.75           8.12       18796    Petrol
# 10  alto 800  2017           2.85           3.60        2135    Petrol
#
#    Seller_Type Transmission  Car_Owner
# 0       Dealer       Manual  1st Owner
# 2       Dealer       Manual  1st Owner
# 3       Dealer       Manual  1st Owner
# 6       Dealer       Manual  2nd Owner
# 10      Dealer       Manual  2nd Owner

# %%
# multiple filters give & condition and encloge with closed brackets
data[(data['Year'] == 2014) & (data['Fuel_Type'] == 'Petrol')]
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                    ritz  2014           3.35          5.590       27000
# 23               alto k10  2014           2.50          3.460       45280
# 41               alto k10  2014           2.55          3.980       46706
# 45                   ciaz  2014           7.50         12.040       15000
# 58                etios g  2014           4.10          6.800       39485
# 89                etios g  2014           4.75          6.760       40000
# 106        Hyosung GT250R  2014           1.35          3.450       16500
# 112         KTM 390 Duke   2014           1.15          2.400        7000
# 136         Honda CBR 150  2014           0.65          1.200       23500
# 144  Bajaj Pulsar  NS 200  2014           0.60          0.990       25000
# 146          Hero Extreme  2014           0.55          0.787       15000
# 154         Yamaha Fazer   2014           0.50          0.880        8000
# ...

# %%
data[(data['Year'] == 2014) & (data['Fuel_Type'] == 'Petrol') & (data['Transmission'] == 'Automatic')]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 45          ciaz  2014           7.50          12.04       15000    Petrol
# 178  TVS Jupyter  2014           0.35           0.52       19000    Petrol
#
#     Seller_Type Transmission  Car_Owner
# 45       Dealer    Automatic  1st Owner
# 178  Individual    Automatic  1st Owner

# %%
data[(data['Year'] == 2017) & (data["Seller_Type"] == 'Individual' )].head(5)
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 27                       swift  2017           6.00           6.49
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Car_Owner
# 27        16200    Petrol  Individual       Manual  1st Owner
# 101        1400    Petrol  Individual       Manual  1st Owner
# 102        4000    Petrol  Individual       Manual  1st Owner
# 103        1200    Petrol  Individual       Manual  1st Owner
# 104        4100    Petrol  Individual       Manual  1st Owner

# %%
# i want  2016 petrol cars & km driven less than 15 k

# %%
data[ (data['Year'] == 2016) & (data['Kms_Driven'] < 15000) & (data['Fuel_Type'] == 'Petrol') ]
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 38                    alto k10  2016           3.00           3.76
# 69               corolla altis  2016          14.25          20.91
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 110                  KTM RC200  2016           1.20           1.78
# 111  Royal Enfield Thunder 350  2016           1.15           1.50
# 120         Bajaj Pulsar RS200  2016           1.05           1.26
# 122   Royal Enfield Bullet 350  2016           1.05           1.17
# 127          Bajaj Avenger 150  2016           0.75           0.80
# 133          Bajaj Avenger 220  2016           0.72           0.95
# 164       Hero Splender iSmart  2016           0.45           0.54
# 165                  Activa 3g  2016           0.45           0.54
# 166           Hero Passion Pro  2016           0.45           0.55
# 205                  grand i10  2016           5.25           5.70
# ...

# %%
data.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Car_Owner
# 0      Dealer       Manual  1st Owner
# 1      Dealer       Manual  1st Owner
# 2      Dealer       Manual  1st Owner
# 3      Dealer       Manual  1st Owner
# 4      Dealer       Manual  2nd Owner

# %%
# to display the selected columns 
data[["Car_Name" , "Year" , "Kms_Driven"]].head(5)
# Out:
#   Car_Name  Year  Kms_Driven
# 0     ritz  2014       27000
# 1      sx4  2013       43000
# 2     ciaz  2017        6900
# 3  wagon r  2011        5200
# 4    swift  2014       42450

# %%
# Check filter and selected columns
data[(data["Year"] == 2014) & (data['Kms_Driven'] < 15000) & (data['Fuel_Type'] == 'Petrol')][["Car_Name" , "Year" , "Kms_Driven"]].head(5)
# Out:
#                 Car_Name  Year  Kms_Driven
# 112        KTM 390 Duke   2014        7000
# 154        Yamaha Fazer   2014        8000
# 172  Bajaj Pulsar 135 LS  2014       13700

# %%
data[(data["Year"] == 2014)][["Car_Name" , "Year" , "Kms_Driven"]].head(5)
# Out:
#     Car_Name  Year  Kms_Driven
# 0       ritz  2014       27000
# 4      swift  2014       42450
# 23  alto k10  2014       45280
# 32     swift  2014       39000
# 33    ertiga  2014       45000

# %%
data.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Car_Owner
# 0      Dealer       Manual  1st Owner
# 1      Dealer       Manual  1st Owner
# 2      Dealer       Manual  1st Owner
# 3      Dealer       Manual  1st Owner
# 4      Dealer       Manual  2nd Owner

# %%
data[data['Year']==2012][["Car_Name"]].count()
# Out:
# Car_Name    23
# dtype: int64

# %%
data[data['Year']==2013][["Car_Name"]].count()
# Out:
# Car_Name    33
# dtype: int64

# %%
data[data['Year']==2014][["Car_Name"]].count()
# Out:
# Car_Name    38
# dtype: int64

# %%
data[data['Year']==2015][["Car_Name"]].count()
# Out:
# Car_Name    61
# dtype: int64

# %%
data['Year'].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007])

# %%
data['Year'].nunique()
# Out:
# 16

# %%
data.groupby("Year")[["Car_Name"]].count()
# Out:
#       Car_Name
# Year
# 2003         2
# 2004         1
# 2005         4
# 2006         4
# 2007         2
# 2008         7
# 2009         6
# 2010        15
# 2011        19
# 2012        23
# 2013        33
# 2014        38
# 2015        61
# 2016        50
# 2017        35
# 2018         1

# %%
# show me the years which is having more than 30 cars

# %%
data.groupby("Year")[["Car_Name"]].count().query("Car_Name > 30")
# Out:
#       Car_Name
# Year
# 2013        33
# 2014        38
# 2015        61
# 2016        50
# 2017        35
