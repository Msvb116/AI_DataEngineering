# %% [markdown]
# ### Python OOPS Concept

# %%
# Classes/ Abstraction / Inheritance

# %%
# oops ---> With oops can become a good coder

# %%
# BMI -- Body Mass Index (try to maintain this), if you do this 80% of health issues will be resolved)

# %%
#  BMI Formula
#BMI = mass(kg) / Height (Square) (mtrs)
#BMI = Weight(kg) / Height (Square) (mtrs)

# %%
height = 165 # cm = 165 * 0.01 -> to convert mt
weight = 75 # kg

# %%
height = 165 * 0.01

# %%
height
# Out:
# 1.6500000000000001

# %%
BMI = 75 / (165 * 0.01) ** 2

# %%
print(BMI)
# Out:
# 27.548209366391177

# %%
# with out class / without OOPS

# %%
# for every patient we have ht & wt we are passing in list variables
p1 = [70,165]  # here we need to find what is 70 & 165
p2 = [80,170]
p3 = [56,148]

# %%
bmi1 = p1[0] / (p1[1] * 0.01) ** 2
bmi2 = p2[0] / (p2[1] * 0.01) ** 2
bmi3 = p3[0] / (p3[1] * 0.01) ** 2

# %%
print("bmi of 01 :",bmi1)
print("bmi of 02 :",bmi2)
print("bmi of 03 :",bmi3)
# Out:
# bmi of 01 : 25.711662075298435
# bmi of 02 : 27.68166089965398
# bmi of 03 : 25.56610664718773

# %%
# with class

# %%
s = "Monday"

# %%
s # is a string

# %%
class bmi:
    weight = 0
    height = 0
    def calculate_bmi(self):
        return self.weight / (self.height * 0.01) ** 2
    def height_in_mts(self):
        return self.height * 0.01

# %% [markdown]
# ##### above in list we didnt know what is in list
# ##### bmi is one class we assigned to P4
# ##### here we are initilizing 0 for ht & wt because we dont have value
# p4 = bmi()

# %%
p4. # i created my own data type here 2 functions are there we can re use it

# %%
s = 'python'
a = [3,4,5,6]
b = 9

# %%
s.   # string supported  functions
 a.  # list supported  functions
 b.  # integer supported  functions

# %%
p4.weight = 75
p4.height = 185

# %%
p4.calculate_bmi()
# Out:
# 21.913805697589478

# %%
p4.height_in_mts()
# Out:
# 1.85

# %%
p5 = bmi()

# %%
p5.weight = 79
p5.height = 175

# %%
p5.calculate_bmi()
# Out:
# 25.79591836734694

# %%
p5.height_in_mts()
# Out:
# 1.75

# %%
# as this method is ok but not best method every time need to assign the values every time

# %%
p6 = bmi()

# %%
p6.weight = 50
p6.height = 165

# %%
p6.calculate_bmi()
# Out:
# 18.36547291092745

# %%
p6.height_in_mts()
# Out:
# 1.6500000000000001

# %%
# class
# It is user defined structure / dttype
# It is like blue print 
# Contains variables and methods
